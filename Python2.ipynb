# %% [markdown]
# <a href="https://colab.research.google.com/github/dindadinho93/Python-Exercise/blob/main/Python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate barcode upc

# %%
from barcode import writer 
#pip install python-barcode

import barcode
from barcode.writer import ImageWriter

number = input("Enter number of barcode :") #input barcode

barcode_format = barcode.get_barcode_class('upc')
my_bar = barcode_format(number, writer=ImageWriter())

my_bar.save('generated_barcode')
# Out:
# Enter number of barcode :123457868534
# 'generated_barcode.png'

# %%
from PIL import Image
Image.open('generated_barcode.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=523x280 at 0x7FD022A7C0D0>

# %% [markdown]
# # Detil Image in Python

# %%
from PIL import Image
Image.open('/content/E3W6xQTUcAYqcvY.jpeg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x410 at 0x7F95561BB8D0>

# %%
img = Image.open('/content/E3W6xQTUcAYqcvY.jpeg')
print(img.format)

print(img.mode)

print(img.size)

print(img.palette)
# Out:
# JPEG
# RGB
# (560, 410)
# None

# %% [markdown]
# #Image Mirror in Python

# %%
img = Image.open('/content/E3W6xQTUcAYqcvY.jpeg')
mirror_img = img.transpose(Image.FLIP_LEFT_RIGHT)
mirror_img.save('bald_mirror.png')
Image.open('bald_mirror.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=560x410 at 0x7F95545C5C10>

# %% [markdown]
# # Track phone python

# %%
#pip install phonenumbers

import phonenumbers
from phonenumbers import geocoder

a = input('Enter phone number : ')
phonenumber = phonenumbers.parse(a)

print(geocoder.description_for_number(phonenumber, 'en'))
# Out:
# Enter phone number : +6285724454139
# Indonesia

# %% [markdown]
# # QR code Python

# %%
pip install pypng
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 58 kB 5.0 MB/s
# ...

# %%
# pip install pyqrcode
# pip install pypng
import pyqrcode
import png 
from PIL import Image

link = 'https://twitter.com/dindadi_'
qr_code = pyqrcode.create(link)
qr_code.png('twitter.png', scale=5)
Image.open('twitter.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=205x205 at 0x7F420036BC90>

# %%
import pandas as pd
df = pd.DataFrame({'x':[1,2,3], 'y':[10,4,5]})
df.sort_values('y')
# Out:
#    x   y
# 1  2   4
# 2  3   5
# 0  1  10
