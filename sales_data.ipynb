# %%
import pandas as pd
import seaborn as sns

# %%
dt = pd.read_csv("D:\KULIAH\sales_data.csv")

# %%
dt.shape
# Out:
# (113036, 18)

# %%
dt.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
dt.corr()
sns.heatmap(dt.corr())
# Out:
# C:\Users\dinda\AppData\Local\Temp\ipykernel_1652\1942682679.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dt.corr()
# C:\Users\dinda\AppData\Local\Temp\ipykernel_1652\1942682679.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dt.corr())
# <AxesSubplot: >

# %%
dt.loc[9]
# Out:
# Date                         2016-02-22
# Day                                  22
# Month                          February
# Year                               2016
# Customer_Age                         35
# Age_Group                Adults (35-64)
# Customer_Gender                       M
# Country                       Australia
# State                          Victoria
# Product_Category            Accessories
# Sub_Category                 Bike Racks
# Product             Hitch Rack - 4-Bike
# Order_Quantity                       21
# Unit_Cost                            45
# Unit_Price                          120
# Profit                             1046
# Cost                                945
# Revenue                            1991
# Name: 9, dtype: object

# %%
dt[dt['Customer_Age']>40]
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# 5       2016-05-15   15       May  2016            47  Adults (35-64)
# 6       2014-05-22   22       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 112999  2016-04-06    6     April  2016            58  Adults (35-64)
# 113028  2013-12-28   28  December  2013            41  Adults (35-64)
# 113029  2015-12-28   28  December  2015            41  Adults (35-64)
# 113030  2014-04-12   12     April  2014            41  Adults (35-64)
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
#
#        Customer_Gender         Country            State Product_Category  \
# ...

# %%
dt['Product_Category'].unique()
# Out:
# array(['Accessories', 'Clothing', 'Bikes'], dtype=object)

# %%
dt[dt['Product_Category'].isin(['Clothing'])]
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 16924   2013-07-20   20      July  2013            32  Young Adults (25-34)
# 16925   2015-07-20   20      July  2015            32  Young Adults (25-34)
# 16926   2013-11-24   24  November  2013            51        Adults (35-64)
# 16927   2015-11-24   24  November  2015            51        Adults (35-64)
# 16928   2014-02-05    5  February  2014            51        Adults (35-64)
# ...            ...  ...       ...   ...           ...                   ...
# 113031  2016-04-12   12     April  2016            41        Adults (35-64)
# 113032  2014-04-02    2     April  2014            18           Youth (<25)
# 113033  2016-04-02    2     April  2016            18           Youth (<25)
# 113034  2014-03-04    4     March  2014            37        Adults (35-64)
# 113035  2016-03-04    4     March  2016            37        Adults (35-64)
#
# ...

# %%
dt['Order_Quantity'].head(20).plot()
# Out:
# <AxesSubplot: >

# %%
dt.groupby('Product_Category')['Profit', 'Cost'].agg('sum')
# Out:
# C:\Users\dinda\AppData\Local\Temp\ipykernel_1652\1724883469.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dt.groupby('Product_Category')['Profit', 'Cost'].agg('sum')
#                     Profit      Cost
# Product_Category
# Accessories        8862377   6255615
# Bikes             20519276  41262858
# Clothing           2839447   5531435

# %%
dt.groupby('Product_Category')['Country'].value_counts().unstack().fillna(0)
# Out:
# Country           Australia  Canada  France  Germany  United Kingdom  \
# Product_Category
# Accessories           13498   10232    6688     6546            8114
# Bikes                  7064    1548    2770     3048            3524
# Clothing               3374    2398    1540     1504            1982
#
# Country           United States
# Product_Category
# Accessories               25042
# Bikes                      8028
# Clothing                   6136

# %%
dt.groupby('Sub_Category').agg({'Profit': sum, 'Cost':sum}).reset_index()
# Out:
#          Sub_Category    Profit      Cost
# 0          Bike Racks    304455    213345
# 1         Bike Stands    201935    142140
# 2   Bottles and Cages    810598    598576
# 3                Caps     77921    470856
# 4            Cleaners    115891     82930
# 5             Fenders    748914    496819
# 6              Gloves    511654    359765
# 7             Helmets   3380203   2360878
# 8     Hydration Packs    572668    417738
# 9             Jerseys    603568   3510174
# 10     Mountain Bikes   8160463  12963063
# 11         Road Bikes  10078875  23284186
# 12             Shorts   1034342    706368
# 13              Socks     93171     54000
# 14    Tires and Tubes   2727713   1943189
# 15      Touring Bikes   2279938   5015609
# 16              Vests    518791    430272

# %%
dt.loc[(dt['Day']==20) & (dt['Customer_Gender']=='F') & 
(dt['State'].isin(['Washington', 'England']))]
# Out:
#               Date  Day      Month  Year  Customer_Age             Age_Group  \
# 144     2013-09-20   20  September  2013            26  Young Adults (25-34)
# 145     2015-09-20   20  September  2015            26  Young Adults (25-34)
# 208     2014-04-20   20      April  2014            31  Young Adults (25-34)
# 209     2016-04-20   20      April  2016            31  Young Adults (25-34)
# 3090    2014-01-20   20    January  2014            50        Adults (35-64)
# ...            ...  ...        ...   ...           ...                   ...
# 111751  2015-12-20   20   December  2015            29  Young Adults (25-34)
# 112784  2013-10-20   20    October  2013            29  Young Adults (25-34)
# 112785  2015-10-20   20    October  2015            29  Young Adults (25-34)
# 112828  2014-03-20   20      March  2014            32  Young Adults (25-34)
# 112829  2016-03-20   20      March  2016            32  Young Adults (25-34)
#
# ...
